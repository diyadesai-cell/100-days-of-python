# %%
#int- whole numbers

# %%
age = 21
score = -5
print(age,score)
# Out:
# 21 -5

# %%
#float- decimal numbers

# %%
height = 5.9
price = 99.99
print(height,price)
# Out:
# 5.9 99.99

# %%
#str- text (string)

# %%
name = "Raj"
city = 'Bhuj'
print(name,city)
# Out:
# Raj Bhuj

# %%
# bool- True or False only

# %%
is_student = True
is_raining = False

# %%
#list- ordered collection (more on Day 16)

# %%
fruits = ["apple", "mango", "banana"]
fruits
# Out:
# ['apple', 'mango', 'banana']

# %%
#NoneType- represents "nothing"

# %%
result = None

# %%
#Check the type of anything using type():

# %%
print(type(42))        
print(type(3.14))      
print(type("hello"))   
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
#Type conversion changing one type to another:

# %%
x = "25"         #str
x = int(x)    

y = 3.99
y = int(y) 

z = 42
z = str(z) 

print(float("3.14"))   
print(bool(0))      
print(bool("hello"))

print(x,y,z)
# Out:
# 3.14
# False
# True
# 25 3 42

# %%
age = input("Enter age: ")  
age = int(age)
# Out:
# Enter age:  21

# %%
#examples

# %%
num = 3
dec = 0.22
word = "hello"
flag = True
print(num,dec,flag,word)
# Out:
# 3 0.22 True hello

# %%
age = "18"
age = int(age)
age = age+2
age
# Out:
# 20

# %%
x = 9.7
x = int(x)       
print(x)
x = str(x) + "!"
print(x)
# Out:
# 9
# 9!

# %%
print(bool(0))
print(bool(1))
print(bool(""))
print(bool("hello"))
print(bool(None))
# Out:
# False
# True
# False
# True
# False

# %%
a = "15"
b = "4"
a = int(a)
b = int(b)
print(a + b)   
print(a - b)   
print(a * b)   
print(a / b)  

print(type(a / b))
# Out:
# 19
# 11
# 60
# 3.75
# <class 'float'>
