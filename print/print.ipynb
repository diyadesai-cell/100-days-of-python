# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print("hello, python!")
# Out:
# hello, python!

# %%
print(2024)
# Out:
# 2024

# %%
a = "raj"
b = "ahmedabad"
print(a)
print(b)
# Out:
# raj
# ahmedabad

# %%
print("python-is-fun")
# Out:
# python-is-fun
